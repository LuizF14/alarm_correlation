# %% [markdown]
# # Exploração dos Dados

# %% [markdown]
# ## Visualização Inicial de Alguns Dados

# %%
from IPython.display import display
import pandas as pd

data = pd.read_csv('data/raw/active_alarms_prod.csv')
data.head()
# Out:
#                              acal_cd_id                      acal_cd_alarm_id  \
# 0  476a7e63-014b-46c0-abaf-e80dc0cacf14  08559a20-f409-4454-9016-1ac36578b4bb
# 1  121548a8-9210-40a7-847f-988781502e3f  104d90ff-0da2-4c93-b7fe-664c17271419
# 2  a801690e-0074-4ad6-835f-9ca8da0c55e8  7b118c2e-f9ed-450b-8a4c-2000c36f7c1c
# 3  776e0483-ac6f-48d0-921e-373a1cb3b5c7  7dbd3557-e9d5-472a-9fdb-af5af2fecea9
# 4  e729be90-d67d-4741-a953-50f3603e5c80  2d2818da-4b0a-4d21-8741-7bf027a369ee
#
#              acal_tx_node                       acal_cd_node_id  \
# 0  SPCTP-V40HPP-SVT201-01  f3ba8721-2bb0-46b3-b4dd-c9255bb7a3ad
# 1  SPCTP-V40HPP-SVT201-01  f3ba8721-2bb0-46b3-b4dd-c9255bb7a3ad
# 2      RJBAR-TAIHUA-ESM31  f02a8eab-0a93-4f87-90f9-3eb96aa9e1aa
# 3      SPCTP-TAIHUA-SVR14  53c8586f-00c4-4f7f-b8b0-ccaa3cf535eb
# 4  spctp-v40hpp-svt231-14  c60cc1af-aa30-491a-a3ef-55c6f8e4d8cd
#
#   acal_tx_node_info                 acal_tx_alert_type  acal_nm_severity  \
# ...

# %% [markdown]
# ## Vendo as colunas

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6881 entries, 0 to 6880
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   acal_cd_id                 6881 non-null   object
#  1   acal_cd_alarm_id           6881 non-null   object
#  2   acal_tx_node               6832 non-null   object
#  3   acal_cd_node_id            6881 non-null   object
#  4   acal_tx_node_info          6877 non-null   object
#  5   acal_tx_alert_type         6881 non-null   object
#  6   acal_nm_severity           6881 non-null   int64
#  7   acal_nm_occurrences        6881 non-null   int64
#  8   acal_dt_last_occurrence    6881 non-null   object
#  9   acal_dt_first_occurrence   6881 non-null   object
#  10  acal_tx_identifier         6881 non-null   object
#  11  acal_nm_probes_alert       6881 non-null   object
#  12  acal_tx_snmp_trap          6881 non-null   object
# ...

# %%
alarm_by_node = data.groupby('acal_tx_node')['acal_cd_alarm_id'].nunique().sort_values(ascending=False)
display(alarm_by_node.to_frame(name='Quantidade de Alarmes'))
# Out:
#                         Quantidade de Alarmes
# acal_tx_node
# SPCTP-IFOHPP-STR04                       2004
# SPCTP-V40HPP-SVT201-01                    538
# spctp-v40hpp-svt231-14                    402
# UC13-PJ041-BARONEZA                       269
# SPCTP-IFOHPP-SWT10                        163
# ...                                       ...
# SPCTP-V02HPP-BLS16                          1
# SPCTP-V02HPP-BLS17                          1
# SPCTP-V02HPP-BLS18                          1
# SPCTP-V02HPP-BLS19                          1
# SPCTP-ENMHPP-LMS03                          1
#
# [531 rows x 1 columns]
