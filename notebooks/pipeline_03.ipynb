# %%
import pandas as pd

data = pd.read_csv('data/raw/active_alarms_prod.csv')

# %%
from src.pipelines.simple_clustering_correlation import SimpleClusteringCorrelation

pipeline = SimpleClusteringCorrelation()

pipeline.train(data)

# %%
import networkx as nx

node_name = "UC13-PJ041-BARONEZA"

node_data = data[data["acal_tx_node"] == node_name]

node_graph = pipeline.inference(node_data)

nx.draw(node_graph)
